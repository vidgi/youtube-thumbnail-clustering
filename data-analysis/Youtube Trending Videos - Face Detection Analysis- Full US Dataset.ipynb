# %% [markdown]
# # Youtube Trending Videos - Thumbnail Analysis

# %% [markdown]
# ### Developing/testing procedure for face detection

# %%
import cv2
import matplotlib.pyplot as plt
from urllib.request import urlopen
from PIL import Image
from skimage import io

def get_detected_face (face):  
    face_img = face.copy()  
    fd = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_alt2.xml')
    fr = fd.detectMultiScale(face_img)  
    for (x,y,width,height) in fr:  
        cv2.rectangle(face_img, (x,y), (x + width, y+height), (255,255,77), 5)             

    if len(fr) == 0:
        result = [False,'']
    else:
        result = [True,fr]# x, y, width, height
              
    return face_img,result

def detectFromUrl(yt_id):
    url ="https://i.ytimg.com/vi/"+yt_id+"/maxresdefault.jpg"
    face1 = io.imread(url)
    face_img,result = get_detected_face(face1)
#     plt.imshow(face_img)
#     plt.show()
    return result

# %%
thumbnails=["gPdUslndvVI",
        "3C66w5Z0ixs",
        "p7HGUZWq_8s",
        "uet14uf9NsE",
        "VIUo6yapDbc",
        "CezxKs9YLv0",
        "GYeKX_LPY9U",
        "9AecsACtkB4",
        "p6RatnMhDj8"]

results=[]
for i in thumbnails:
    results.append(detectFromUrl(i))

results
# Out:
# [[True, array([[256, 239, 204, 204]], dtype=int32)],
#  [True, array([[814,  44,  62,  62]], dtype=int32)],
#  [True,
#   array([[726, 132, 318, 318],
#          [162, 145, 307, 307]], dtype=int32)],
#  [True,
#   array([[219, 151, 201, 201],
#          [591, 210, 181, 181]], dtype=int32)],
#  [True,
#   array([[ 423,  192,   84,   84],
#          [ 160,  266,   82,   82],
#          [1031,  261,   90,   90],
#          [1133,  264,  117,  117],
#          [ 906,  374,   84,   84],
#          [ 303,  433,   70,   70]], dtype=int32)],
#  [True, array([[570,  86, 173, 173]], dtype=int32)],
#  [True, array([[ 21, 275,  51,  51]], dtype=int32)],
#  [False, ''],
#  [True, array([[736, 101, 280, 280]], dtype=int32)]]

# %% [markdown]
# ## Detecting Faces in Youtube US Trending Dataset

# %% [markdown]
# ### Library Imports

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

from datetime import datetime
import warnings

import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('seaborn-whitegrid')
font = {'size' : 12}
figure = {'titlesize' : 18}
plt.rc('font', **font)
plt.rc('figure', **figure)

import seaborn as sns
sns.set_style("whitegrid")
sns.set(font_scale=1.2)

from tqdm import tqdm
import missingno as msno

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv("US_youtube_trending_data.csv")
df.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# 0  2020-08-12T00:00:00Z  brawadis|prank|basketball|skits|ghost|funny vi...
# 1  2020-08-12T00:00:00Z  Apex Legends|Apex Legends characters|new Apex ...
# 2  2020-08-12T00:00:00Z  jacksepticeye|funny|funny meme|memes|jacksepti...
# 3  2020-08-12T00:00:00Z  xxl freshman|xxl freshmen|2020 xxl freshman|20...
# 4  2020-08-12T00:00:00Z  The LaBrant Family|DIY|Interior Design|Makeove...
#
#    view_count   likes  dislikes  comment_count  \
# 0     1514614  156908      5855          35313
# 1     2381688  146739      2794          16549
# 2     2038853  353787      2628          40221
# 3      496771   23251      1856           7647
# 4     1123889   45802       964           2196
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg              False
# 1  https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg              False
# 2  https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg              False
# 3  https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg              False
# 4  https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg              False
#
#    ratings_disabled                                        description
# 0             False  SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...
# 1             False  While running her own modding shop, Ramya Pare...
# 2             False  I left youtube for a month and this is what ha...
# 3             False  Subscribe to XXL → http://bit.ly/subscribe-xxl...
# 4             False  Transforming The LaBrant Family's empty white ...

# %%
ids = df['video_id'].tolist()

# ids = ids[0:10]

results=[]
for i in ids:
    try:
        results.append(detectFromUrl(i))
    except:
        results.append(['exception',''])
results
# Out:
# [[True, array([[814,  44,  62,  62]], dtype=int32)],
#  [True,
#   array([[776, 134, 235, 235],
#          [466, 102, 358, 358]], dtype=int32)],
#  [True, array([[390,  14, 549, 549]], dtype=int32)],
#  [True,
#   array([[1062,  138,   56,   56],
#          [ 887,  230,   34,   34],
#          [ 990,  218,   44,   44],
#          [ 932,  337,   50,   50],
#          [ 998,  346,   51,   51]], dtype=int32)],
#  [True,
#   array([[ 423,  192,   84,   84],
#          [ 160,  266,   82,   82],
#          [1031,  261,   90,   90],
#          [1133,  264,  117,  117],
#          [ 906,  374,   84,   84],
#          [ 303,  433,   70,   70]], dtype=int32)],
#  [True, array([[545,  44,  59,  59]], dtype=int32)],
#  [True,
#   array([[219, 151, 201, 201],
#          [591, 210, 181, 181]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 488,   44,   75,   75],
#          [ 767,  112,   62,   62],
#          [1129,  245,   63,   63],
#          [1042,  538,   66,   66]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[152, 111, 234, 234],
#          [793, 108, 243, 243]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  ['exception', ''],
#  [True,
#   array([[524, 152, 121, 121],
#          [178, 359,  28,  28]], dtype=int32)],
#  [True, array([[332,  87, 512, 512]], dtype=int32)],
#  [True, array([[256, 239, 204, 204]], dtype=int32)],
#  [True, array([[423, 146, 386, 386]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True, array([[389, 150, 220, 220]], dtype=int32)],
#  [True,
#   array([[824,  81,  63,  63],
#          [ 71, 139,  69,  69],
#          [305, 385,  82,  82]], dtype=int32)],
#  [True,
#   array([[726, 132, 318, 318],
#          [162, 145, 307, 307]], dtype=int32)],
#  [True,
#   array([[365, 143, 254, 254],
#          [ 71, 632,  63,  63]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[560,  95, 225, 225]], dtype=int32)],
#  [True, array([[460, 117, 238, 238]], dtype=int32)],
#  [True,
#   array([[ 887,   61,  175,  175],
#          [ 445,  171,  317,  317],
#          [1057,  593,  122,  122]], dtype=int32)],
#  [True, array([[570,  86, 173, 173]], dtype=int32)],
#  [True, array([[ 21, 275,  51,  51]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[534, 137, 244, 244]], dtype=int32)],
#  [True,
#   array([[579, 121, 215, 215],
#          [ 10, 388, 100, 100]], dtype=int32)],
#  [True,
#   array([[384,  43, 153, 153],
#          [972, 117, 130, 130],
#          [418, 149,  84,  84]], dtype=int32)],
#  [True, array([[435, 128, 282, 282]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[861,  58, 142, 142],
#          [278,  67, 264, 264]], dtype=int32)],
#  [True,
#   array([[895,  61, 283, 283],
#          [141,  85, 270, 270]], dtype=int32)],
#  [False, ''],
#  [True, array([[833,   5,  43,  43]], dtype=int32)],
#  [True, array([[736, 101, 280, 280]], dtype=int32)],
#  [True,
#   array([[ 504,  166,   52,   52],
#          [ 910,  247,   47,   47],
#          [1126,  278,   41,   41]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[215, 102, 224, 224],
#          [864, 104, 232, 232]], dtype=int32)],
#  [True,
#   array([[964, 232,  90,  90],
#          [498, 420, 221, 221]], dtype=int32)],
#  [False, ''],
#  [True, array([[527, 125, 183, 183]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[172, 100, 289, 289],
#          [810, 160, 233, 233]], dtype=int32)],
#  [True,
#   array([[764, 149, 209, 209],
#          [542, 228, 200, 200],
#          [303, 317,  65,  65]], dtype=int32)],
#  [True,
#   array([[290, 145,  88,  88],
#          [934, 194,  69,  69]], dtype=int32)],
#  [True, array([[1018,  588,   56,   56]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  ['exception', ''],
#  [True, array([[570, 274,  98,  98]], dtype=int32)],
#  [True,
#   array([[106,  56, 310, 310],
#          [646,  65, 282, 282],
#          [199, 346, 114, 114]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[  93,  118,  216,  216],
#          [1084,  216,   65,   65],
#          [1134,  216,   65,   65]], dtype=int32)],
#  [True, array([[290, 258, 104, 104]], dtype=int32)],
#  [True,
#   array([[829,  70, 398, 398],
#          [440, 116, 414, 414],
#          [155, 109, 336, 336]], dtype=int32)],
#  [True,
#   array([[189, 120, 373, 373],
#          [747, 470,  48,  48],
#          [748, 564,  61,  61]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[861,  80, 221, 221],
#          [200,  79, 230, 230]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[976,  58, 273, 273],
#          [553, 183, 198, 198]], dtype=int32)],
#  [True,
#   array([[617,  68, 203, 203],
#          [ 16, 567,  47,  47]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[727, 117, 407, 407],
#          [ 82, 455, 152, 152]], dtype=int32)],
#  [False, ''],
#  [True, array([[759, 313,  66,  66]], dtype=int32)],
#  [True,
#   array([[115, 108, 134, 134],
#          [966, 196, 235, 235],
#          [315, 208, 118, 118]], dtype=int32)],
#  [True, array([[544,  83, 176, 176]], dtype=int32)],
#  [True, array([[397, 111, 385, 385]], dtype=int32)],
#  [True, array([[648, 209,  23,  23]], dtype=int32)],
#  [True, array([[486, 150, 101, 101]], dtype=int32)],
#  [True,
#   array([[219,  65, 165, 165],
#          [862,  49, 143, 143]], dtype=int32)],
#  [True,
#   array([[574, 116, 190, 190],
#          [998, 144, 192, 192]], dtype=int32)],
#  [True, array([[984, 180,  45,  45]], dtype=int32)],
#  [True, array([[394, 123,  75,  75]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[539, 111, 188, 188],
#          [336, 274,  89,  89],
#          [167, 287,  71,  71],
#          [858, 316,  89,  89],
#          [987, 315,  69,  69]], dtype=int32)],
#  [True,
#   array([[ 851,   63,  112,  112],
#          [1024,  127,  113,  113]], dtype=int32)],
#  [True, array([[258, 172, 272, 272]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[591, 230, 100, 100]], dtype=int32)],
#  [False, ''],
#  [True, array([[510, 384,  84,  84]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[ 765,   10,  180,  180],
#          [1008,  120,  126,  126]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[195,  98, 169, 169],
#          [228, 219,  96,  96]], dtype=int32)],
#  [True,
#   array([[781, 162, 329, 329],
#          [ 60, 182, 353, 353],
#          [455, 204, 320, 320]], dtype=int32)],
#  [True, array([[600, 256,  58,  58]], dtype=int32)],
#  [False, ''],
#  [True, array([[178,  64, 305, 305]], dtype=int32)],
#  [True, array([[733,  88, 132, 132]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[979,  31,  63,  63],
#          [955,  94, 159, 159],
#          [224, 109, 163, 163]], dtype=int32)],
#  [False, ''],
#  [True, array([[349, 537,  73,  73]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[644, 195,  43,  43],
#          [987, 301,  45,  45]], dtype=int32)],
#  [True, array([[393,  34, 197, 197]], dtype=int32)],
#  [True,
#   array([[1057,   79,  138,  138],
#          [1119,  209,  107,  107]], dtype=int32)],
#  [True,
#   array([[625,  96, 107, 107],
#          [850, 139, 115, 115],
#          [155, 139, 332, 332]], dtype=int32)],
#  [True, array([[544,  91, 250, 250]], dtype=int32)],
#  [True,
#   array([[824,  90, 304, 304],
#          [273, 160, 257, 257],
#          [180, 455,  46,  46]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[619, 252,  42,  42],
#          [900, 228,  54,  54],
#          [710, 277,  43,  43],
#          [739, 394,  48,  48],
#          [344, 436,  43,  43],
#          [455, 416,  46,  46],
#          [244, 451,  43,  43],
#          [964, 461,  41,  41]], dtype=int32)],
#  [True,
#   array([[548,  94, 105, 105],
#          [505, 125, 125, 125],
#          [546, 179, 106, 106],
#          [510, 212, 128, 128],
#          [504, 300, 125, 125],
#          [540, 351, 106, 106]], dtype=int32)],
#  [True, array([[447, 480,  48,  48]], dtype=int32)],
#  [True, array([[364,  87, 480, 480]], dtype=int32)],
#  [True, array([[157, 139, 389, 389]], dtype=int32)],
#  [True,
#   array([[858,  99, 262, 262],
#          [945, 372,  64,  64]], dtype=int32)],
#  [False, ''],
#  [True, array([[955,  23, 114, 114]], dtype=int32)],
#  [True, array([[1038,   70,  189,  189]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[541, 127, 238, 238]], dtype=int32)],
#  [True,
#   array([[743, 112, 258, 258],
#          [280, 113, 302, 302]], dtype=int32)],
#  [True, array([[456,  41,  84,  84]], dtype=int32)],
#  [True, array([[179,  80, 390, 390]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[401,  42, 486, 486],
#          [ 63, 183, 394, 394]], dtype=int32)],
#  [True, array([[960, 125,  91,  91]], dtype=int32)],
#  [False, ''],
#  [True, array([[ 69, 198, 460, 460]], dtype=int32)],
#  [True,
#   array([[920, 132, 126, 126],
#          [303, 209, 136, 136]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[201, 230, 410, 410],
#          [847, 160, 273, 273]], dtype=int32)],
#  [False, ''],
#  [True, array([[387,  10, 331, 331]], dtype=int32)],
#  [False, ''],
#  [True, array([[540, 121, 361, 361]], dtype=int32)],
#  [True,
#   array([[877, 427,  59,  59],
#          [884, 448,  53,  53]], dtype=int32)],
#  [True,
#   array([[960,  87,  92,  92],
#          [801, 326,  76,  76]], dtype=int32)],
#  [True,
#   array([[603,  66, 206, 206],
#          [795,  76, 284, 284],
#          [450, 261, 262, 262]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[ 27, 410,  53,  53]], dtype=int32)],
#  [True, array([[601, 170, 318, 318]], dtype=int32)],
#  [True,
#   array([[851,  84, 228, 228],
#          [205,  85, 220, 220]], dtype=int32)],
#  [True, array([[284, 119, 123, 123]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[503,  42, 101, 101],
#          [872, 102,  78,  78],
#          [878, 268,  47,  47]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[288, 209, 151, 151]], dtype=int32)],
#  [True,
#   array([[1140,  370,   24,   24],
#          [ 464,  312,  111,  111],
#          [ 493,  354,  106,  106]], dtype=int32)],
#  [False, ''],
#  [True, array([[668, 611,  58,  58]], dtype=int32)],
#  [True,
#   array([[  52,  142,   29,   29],
#          [ 549,  144,  115,  115],
#          [ 257,  153,  105,  105],
#          [ 841,  331,  123,  123],
#          [ 415,  349,  106,  106],
#          [ 184,  355,  121,  121],
#          [ 576,  370,  110,  110],
#          [1064,  365,  112,  112]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[1126,  536,   98,   98]], dtype=int32)],
#  [True, array([[241, 390, 127, 127]], dtype=int32)],
#  [True, array([[193,  24, 356, 356]], dtype=int32)],
#  [True,
#   array([[ 172,   88,  123,  123],
#          [1127,  232,   48,   48],
#          [ 531,  221,  151,  151]], dtype=int32)],
#  [True,
#   array([[1078,   57,   62,   62],
#          [ 686,  247,   68,   68],
#          [ 414,  491,  122,  122]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[435,  65, 137, 137]], dtype=int32)],
#  [True,
#   array([[ 181,   25,  210,  210],
#          [ 545,  140,  208,  208],
#          [1013,  270,  239,  239]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[273, 466, 198, 198]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [False, ''],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[250,  91, 376, 376],
#          [757, 139, 387, 387],
#          [168, 322,  54,  54]], dtype=int32)],
#  [True,
#   array([[587, 135, 135, 135],
#          [921, 159, 159, 159],
#          [457, 255,  89,  89]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[155, 130,  78,  78],
#          [819, 119, 304, 304],
#          [254, 255, 205, 205]], dtype=int32)],
#  [True, array([[618, 269,  51,  51]], dtype=int32)],
#  [True, array([[812,  10, 153, 153]], dtype=int32)],
#  [True,
#   array([[755, 113, 331, 331],
#          [ 20, 168,  50,  50]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[1048,  568,  102,  102],
#          [1052,  649,   54,   54]], dtype=int32)],
#  [True, array([[865, 114, 351, 351]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [True,
#   array([[249,  47,  76,  76],
#          [174, 156,  59,  59],
#          [118, 283, 135, 135]], dtype=int32)],
#  [True, array([[411, 525,  44,  44]], dtype=int32)],
#  [True, array([[549, 148, 163, 163]], dtype=int32)],
#  [False, ''],
#  [True, array([[814,  44,  62,  62]], dtype=int32)],
#  [True,
#   array([[252,  43,  77,  77],
#          [961, 112,  67,  67]], dtype=int32)],
#  [True,
#   array([[979, 132, 118, 118],
#          [272, 169,  52,  52]], dtype=int32)],
#  ['exception', ''],
#  ['exception', ''],
#  [True, array([[390,  14, 549, 549]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[776, 134, 235, 235],
#          [466, 102, 358, 358]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[ 423,  192,   84,   84],
#          [ 160,  266,   82,   82],
#          [1031,  261,   90,   90],
#          [1133,  264,  117,  117],
#          [ 906,  374,   84,   84],
#          [ 303,  433,   70,   70]], dtype=int32)],
#  [True,
#   array([[1062,  138,   56,   56],
#          [ 887,  230,   34,   34],
#          [ 990,  218,   44,   44],
#          [ 932,  337,   50,   50],
#          [ 998,  346,   51,   51]], dtype=int32)],
#  [True, array([[385, 445,  69,  69]], dtype=int32)],
#  [False, ''],
#  [True, array([[545,  44,  59,  59]], dtype=int32)],
#  [True, array([[560,  95, 225, 225]], dtype=int32)],
#  [True,
#   array([[153, 100, 398, 398],
#          [177, 519, 112, 112]], dtype=int32)],
#  [True, array([[ 87,  43, 434, 434]], dtype=int32)],
#  [True,
#   array([[410, 206,  29,  29],
#          [297, 242,  30,  30]], dtype=int32)],
#  [True,
#   array([[219, 151, 201, 201],
#          [591, 210, 181, 181]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[ 488,   44,   75,   75],
#          [ 767,  112,   62,   62],
#          [1129,  245,   63,   63],
#          [1042,  538,   66,   66]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[152, 111, 234, 234],
#          [793, 108, 243, 243]], dtype=int32)],
#  [True, array([[256, 239, 204, 204]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[534, 216, 132, 132],
#          [440, 246, 103, 103],
#          [ 69, 266,  86,  86],
#          [384, 285,  54,  54],
#          [911, 322,  53,  53],
#          [314, 302,  56,  56],
#          [212, 303,  74,  74]], dtype=int32)],
#  [True, array([[332,  87, 512, 512]], dtype=int32)],
#  [True,
#   array([[524, 152, 121, 121],
#          [178, 359,  28,  28]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True, array([[423, 146, 386, 386]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[882, 119, 217, 217],
#          [665, 183, 118, 118],
#          [468, 290,  52,  52]], dtype=int32)],
#  [True,
#   array([[726, 132, 318, 318],
#          [162, 145, 307, 307]], dtype=int32)],
#  [False, ''],
#  [True, array([[389, 150, 220, 220]], dtype=int32)],
#  [True,
#   array([[365, 143, 254, 254],
#          [ 71, 632,  63,  63]], dtype=int32)],
#  [True,
#   array([[ 887,   61,  175,  175],
#          [ 445,  171,  317,  317],
#          [1057,  593,  122,  122]], dtype=int32)],
#  [False, ''],
#  [True, array([[ 46, 494,  72,  72]], dtype=int32)],
#  [True, array([[434,  69, 170, 170]], dtype=int32)],
#  [False, ''],
#  [True, array([[ 21, 275,  51,  51]], dtype=int32)],
#  [True, array([[570,  86, 173, 173]], dtype=int32)],
#  [True, array([[460, 117, 238, 238]], dtype=int32)],
#  [True,
#   array([[ 199,  320,   72,   72],
#          [1100,  628,   41,   41],
#          [1070,  629,   43,   43]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[579, 121, 215, 215],
#          [ 10, 388, 100, 100]], dtype=int32)],
#  [True, array([[534, 137, 244, 244]], dtype=int32)],
#  [True,
#   array([[ 504,  166,   52,   52],
#          [ 910,  247,   47,   47],
#          [1126,  278,   41,   41]], dtype=int32)],
#  [True,
#   array([[824,  81,  63,  63],
#          [ 71, 139,  69,  69],
#          [305, 385,  82,  82]], dtype=int32)],
#  [True, array([[435, 128, 282, 282]], dtype=int32)],
#  [True,
#   array([[964, 232,  90,  90],
#          [498, 420, 221, 221]], dtype=int32)],
#  [True,
#   array([[972, 117, 130, 130],
#          [384,  43, 153, 153],
#          [418, 149,  84,  84]], dtype=int32)],
#  [True,
#   array([[215, 102, 224, 224],
#          [864, 104, 232, 232]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [True, array([[736, 101, 280, 280]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[895,  61, 283, 283],
#          [141,  85, 270, 270]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[764, 149, 209, 209],
#          [542, 228, 200, 200],
#          [303, 317,  65,  65]], dtype=int32)],
#  [True, array([[527, 125, 183, 183]], dtype=int32)],
#  [True, array([[570, 274,  98,  98]], dtype=int32)],
#  [True, array([[1018,  588,   56,   56]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[519,  72, 160, 160]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[290, 145,  88,  88],
#          [934, 194,  69,  69]], dtype=int32)],
#  [True, array([[833,   5,  43,  43]], dtype=int32)],
#  [True,
#   array([[172, 100, 289, 289],
#          [810, 160, 233, 233]], dtype=int32)],
#  [True, array([[258, 172, 272, 272]], dtype=int32)],
#  [True,
#   array([[155, 109, 336, 336],
#          [829,  70, 398, 398],
#          [440, 116, 414, 414]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[106,  56, 310, 310],
#          [646,  65, 282, 282],
#          [199, 346, 114, 114]], dtype=int32)],
#  [True,
#   array([[861,  58, 142, 142],
#          [278,  67, 264, 264]], dtype=int32)],
#  [True,
#   array([[189, 120, 373, 373],
#          [747, 470,  48,  48],
#          [748, 564,  61,  61]], dtype=int32)],
#  [True,
#   array([[  93,  118,  216,  216],
#          [1084,  216,   65,   65],
#          [1134,  216,   65,   65]], dtype=int32)],
#  [True, array([[290, 258, 104, 104]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[984, 180,  45,  45]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[861,  80, 221, 221],
#          [200,  79, 230, 230]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[759, 313,  66,  66]], dtype=int32)],
#  [True,
#   array([[617,  68, 203, 203],
#          [ 16, 567,  47,  47]], dtype=int32)],
#  [True, array([[648, 209,  23,  23]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[976,  58, 273, 273],
#          [553, 183, 198, 198]], dtype=int32)],
#  [True,
#   array([[539, 111, 188, 188],
#          [336, 274,  89,  89],
#          [167, 287,  71,  71],
#          [858, 316,  89,  89],
#          [987, 315,  69,  69]], dtype=int32)],
#  [True,
#   array([[727, 117, 407, 407],
#          [ 82, 455, 152, 152]], dtype=int32)],
#  [True,
#   array([[115, 108, 134, 134],
#          [966, 196, 235, 235],
#          [315, 208, 118, 118]], dtype=int32)],
#  [True, array([[397, 111, 385, 385]], dtype=int32)],
#  [True,
#   array([[219,  65, 165, 165],
#          [862,  49, 143, 143]], dtype=int32)],
#  [True, array([[486, 150, 101, 101]], dtype=int32)],
#  [True, array([[394, 123,  75,  75]], dtype=int32)],
#  ['exception', ''],
#  ['exception', ''],
#  [True, array([[510, 384,  84,  84]], dtype=int32)],
#  [True, array([[597, 135, 290, 290]], dtype=int32)],
#  [True, array([[591, 230, 100, 100]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[574, 116, 190, 190],
#          [998, 144, 192, 192]], dtype=int32)],
#  [True,
#   array([[ 765,   10,  180,  180],
#          [1008,  120,  126,  126]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [True,
#   array([[781, 162, 329, 329],
#          [ 60, 182, 353, 353],
#          [455, 204, 320, 320]], dtype=int32)],
#  [True, array([[600, 256,  58,  58]], dtype=int32)],
#  [True,
#   array([[195,  98, 169, 169],
#          [228, 219,  96,  96]], dtype=int32)],
#  [True, array([[733,  88, 132, 132]], dtype=int32)],
#  [False, ''],
#  [True, array([[178,  64, 305, 305]], dtype=int32)],
#  [True, array([[544,  83, 176, 176]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[349, 537,  73,  73]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True, array([[364,  87, 480, 480]], dtype=int32)],
#  [True,
#   array([[979,  31,  63,  63],
#          [955,  94, 159, 159],
#          [224, 109, 163, 163]], dtype=int32)],
#  [True,
#   array([[1024,  127,  113,  113],
#          [ 851,   63,  112,  112]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[1057,   79,  138,  138],
#          [1119,  209,  107,  107]], dtype=int32)],
#  [True, array([[393,  34, 197, 197]], dtype=int32)],
#  [True,
#   array([[625,  96, 107, 107],
#          [850, 139, 115, 115],
#          [155, 139, 332, 332]], dtype=int32)],
#  [True, array([[447, 480,  48,  48]], dtype=int32)],
#  [True,
#   array([[644, 195,  43,  43],
#          [987, 301,  45,  45]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[273, 160, 257, 257],
#          [824,  90, 304, 304],
#          [180, 455,  46,  46]], dtype=int32)],
#  [True,
#   array([[619, 252,  42,  42],
#          [710, 277,  43,  43],
#          [900, 228,  54,  54],
#          [739, 394,  48,  48],
#          [455, 416,  46,  46],
#          [344, 436,  43,  43],
#          [244, 451,  43,  43],
#          [964, 461,  41,  41]], dtype=int32)],
#  [True, array([[544,  91, 250, 250]], dtype=int32)],
#  [True,
#   array([[505, 125, 125, 125],
#          [548,  94, 105, 105],
#          [546, 179, 106, 106],
#          [510, 212, 128, 128],
#          [504, 300, 125, 125],
#          [540, 351, 106, 106]], dtype=int32)],
#  [True, array([[157, 139, 389, 389]], dtype=int32)],
#  [True,
#   array([[858,  99, 262, 262],
#          [945, 372,  64,  64]], dtype=int32)],
#  [False, ''],
#  [True, array([[1038,   70,  189,  189]], dtype=int32)],
#  [True, array([[955,  23, 114, 114]], dtype=int32)],
#  [False, ''],
#  [True, array([[541, 127, 238, 238]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[743, 112, 258, 258],
#          [280, 113, 302, 302]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[ 27, 410,  53,  53]], dtype=int32)],
#  [True, array([[456,  41,  84,  84]], dtype=int32)],
#  [True, array([[179,  80, 390, 390]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[401,  42, 486, 486],
#          [ 63, 183, 394, 394]], dtype=int32)],
#  [True, array([[960, 125,  91,  91]], dtype=int32)],
#  [True, array([[ 69, 198, 460, 460]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[877, 427,  59,  59],
#          [884, 448,  53,  53]], dtype=int32)],
#  [True, array([[540, 121, 361, 361]], dtype=int32)],
#  [True,
#   array([[847, 160, 273, 273],
#          [201, 230, 410, 410]], dtype=int32)],
#  [True,
#   array([[603,  66, 206, 206],
#          [795,  76, 284, 284],
#          [450, 261, 262, 262]], dtype=int32)],
#  [True,
#   array([[920, 132, 126, 126],
#          [303, 209, 136, 136]], dtype=int32)],
#  [True, array([[387,  10, 331, 331]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[960,  87,  92,  92],
#          [801, 326,  76,  76]], dtype=int32)],
#  [True, array([[601, 170, 318, 318]], dtype=int32)],
#  [True, array([[284, 119, 123, 123]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[503,  42, 101, 101],
#          [872, 102,  78,  78],
#          [878, 268,  47,  47]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[205,  85, 220, 220],
#          [851,  84, 228, 228]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[1140,  370,   24,   24],
#          [ 464,  312,  111,  111],
#          [ 493,  354,  106,  106]], dtype=int32)],
#  [False, ''],
#  [True, array([[288, 209, 151, 151]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[668, 611,  58,  58]], dtype=int32)],
#  [True,
#   array([[  52,  142,   29,   29],
#          [ 549,  144,  115,  115],
#          [ 257,  153,  105,  105],
#          [ 841,  331,  123,  123],
#          [ 415,  349,  106,  106],
#          [1064,  365,  112,  112],
#          [ 184,  355,  121,  121],
#          [ 576,  370,  110,  110]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[1126,  536,   98,   98]], dtype=int32)],
#  [True, array([[241, 390, 127, 127]], dtype=int32)],
#  [True,
#   array([[ 172,   88,  123,  123],
#          [1127,  232,   48,   48],
#          [ 531,  221,  151,  151]], dtype=int32)],
#  [True, array([[193,  24, 356, 356]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[326,  98,  78,  78],
#          [584, 189, 147, 147]], dtype=int32)],
#  [True, array([[802, 224, 140, 140]], dtype=int32)],
#  [True,
#   array([[581,  95, 136, 136],
#          [529, 403,  54,  54],
#          [474, 349, 158, 158]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[  30,   24,  187,  187],
#          [1037,   80,  225,  225],
#          [ 703,  262,  119,  119],
#          [ 501,  278,  124,  124],
#          [ 899,  316,  184,  184],
#          [ 154,  308,  137,  137],
#          [ 569,  437,  118,  118],
#          [   6,  440,  115,  115],
#          [ 763,  417,  122,  122],
#          [ 362,  458,  141,  141]], dtype=int32)],
#  [True, array([[586,  88, 303, 303]], dtype=int32)],
#  [True, array([[1132,   79,   28,   28]], dtype=int32)],
#  [True,
#   array([[375, 203,  53,  53],
#          [909, 212,  50,  50],
#          [185, 418,  54,  54]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[951, 179, 190, 190],
#          [159, 183, 198, 198]], dtype=int32)],
#  [True, array([[645, 193, 243, 243]], dtype=int32)],
#  [True, array([[549, 148, 163, 163]], dtype=int32)],
#  [True,
#   array([[633, 211, 187, 187],
#          [638, 444, 160, 160]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[ 72, 287, 194, 194]], dtype=int32)],
#  [True, array([[496, 121, 178, 178]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[853, 158,  44,  44],
#          [207, 489,  82,  82]], dtype=int32)],
#  [True, array([[453,  72, 149, 149]], dtype=int32)],
#  [False, ''],
#  [True, array([[583,  80, 101, 101]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[845, 318,  50,  50],
#          [310, 270, 128, 128],
#          [917, 271, 131, 131],
#          [662, 497,  66,  66]], dtype=int32)],
#  [True,
#   array([[457, 120, 344, 344],
#          [205,  41, 217, 217]], dtype=int32)],
#  [True,
#   array([[950, 251,  56,  56],
#          [775, 573,  58,  58]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[961, 112,  67,  67],
#          [252,  43,  77,  77]], dtype=int32)],
#  [False, ''],
#  [True, array([[814,  44,  62,  62]], dtype=int32)],
#  [False, ''],
#  [True, array([[234, 198, 347, 347]], dtype=int32)],
#  [False, ''],
#  [True, array([[555, 417, 110, 110]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[902, 135, 120, 120],
#          [755, 250,  67,  67]], dtype=int32)],
#  [True,
#   array([[979, 132, 118, 118],
#          [272, 169,  52,  52]], dtype=int32)],
#  [True,
#   array([[610, 126,  58,  58],
#          [483, 137,  55,  55],
#          [596, 354,  69,  69],
#          [180, 388,  65,  65]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[390,  14, 549, 549]], dtype=int32)],
#  [True,
#   array([[ 423,  192,   84,   84],
#          [ 160,  266,   82,   82],
#          [1031,  261,   90,   90],
#          [1133,  264,  117,  117],
#          [ 906,  374,   84,   84],
#          [ 303,  433,   70,   70]], dtype=int32)],
#  [True, array([[385, 445,  69,  69]], dtype=int32)],
#  [True, array([[545,  44,  59,  59]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[219, 151, 201, 201],
#          [591, 210, 181, 181]], dtype=int32)],
#  [True, array([[ 87,  43, 434, 434]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[256, 239, 204, 204]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[534, 216, 132, 132],
#          [440, 246, 103, 103],
#          [ 69, 266,  86,  86],
#          [384, 285,  54,  54],
#          [911, 322,  53,  53],
#          [314, 302,  56,  56],
#          [212, 303,  74,  74]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 488,   44,   75,   75],
#          [ 767,  112,   62,   62],
#          [1129,  245,   63,   63],
#          [1042,  538,   66,   66]], dtype=int32)],
#  [True,
#   array([[152, 111, 234, 234],
#          [793, 108, 243, 243]], dtype=int32)],
#  [True,
#   array([[153, 100, 398, 398],
#          [177, 519, 112, 112]], dtype=int32)],
#  [False, ''],
#  [True, array([[389, 150, 220, 220]], dtype=int32)],
#  [False, ''],
#  [True, array([[332,  87, 512, 512]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[895,  61, 283, 283],
#          [141,  85, 270, 270]], dtype=int32)],
#  [True,
#   array([[524, 152, 121, 121],
#          [178, 359,  28,  28]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  ['exception', ''],
#  [True, array([[423, 146, 386, 386]], dtype=int32)],
#  [True,
#   array([[726, 132, 318, 318],
#          [162, 145, 307, 307]], dtype=int32)],
#  [True,
#   array([[882, 119, 217, 217],
#          [665, 183, 118, 118],
#          [468, 290,  52,  52]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 887,   61,  175,  175],
#          [ 445,  171,  317,  317],
#          [1057,  593,  122,  122]], dtype=int32)],
#  [False, ''],
#  [True, array([[ 46, 494,  72,  72]], dtype=int32)],
#  [True,
#   array([[ 199,  320,   72,   72],
#          [1100,  628,   41,   41],
#          [1070,  629,   43,   43]], dtype=int32)],
#  [True,
#   array([[365, 143, 254, 254],
#          [ 71, 632,  63,  63]], dtype=int32)],
#  [True, array([[434,  69, 170, 170]], dtype=int32)],
#  [True, array([[476, 205, 208, 208]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[ 21, 275,  51,  51]], dtype=int32)],
#  [True, array([[460, 117, 238, 238]], dtype=int32)],
#  [True, array([[570,  86, 173, 173]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 504,  166,   52,   52],
#          [ 910,  247,   47,   47],
#          [1126,  278,   41,   41]], dtype=int32)],
#  [True,
#   array([[579, 121, 215, 215],
#          [ 10, 388, 100, 100]], dtype=int32)],
#  [True,
#   array([[964, 232,  90,  90],
#          [498, 420, 221, 221]], dtype=int32)],
#  [False, ''],
#  [True, array([[534, 137, 244, 244]], dtype=int32)],
#  [True, array([[435, 128, 282, 282]], dtype=int32)],
#  [True,
#   array([[215, 102, 224, 224],
#          [864, 104, 232, 232]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[736, 101, 280, 280]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[764, 149, 209, 209],
#          [542, 228, 200, 200],
#          [303, 317,  65,  65]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[829,  70, 398, 398],
#          [440, 116, 414, 414],
#          [155, 109, 336, 336]], dtype=int32)],
#  [False, ''],
#  [True, array([[570, 274,  98,  98]], dtype=int32)],
#  [False, ''],
#  [True, array([[1018,  588,   56,   56]], dtype=int32)],
#  [True, array([[597, 135, 290, 290]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[527, 125, 183, 183]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[290, 145,  88,  88],
#          [934, 194,  69,  69]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[172, 100, 289, 289],
#          [810, 160, 233, 233]], dtype=int32)],
#  [False, ''],
#  [True, array([[258, 172, 272, 272]], dtype=int32)],
#  [True,
#   array([[106,  56, 310, 310],
#          [646,  65, 282, 282],
#          [199, 346, 114, 114]], dtype=int32)],
#  [True, array([[984, 180,  45,  45]], dtype=int32)],
#  [True,
#   array([[189, 120, 373, 373],
#          [747, 470,  48,  48],
#          [748, 564,  61,  61]], dtype=int32)],
#  [True,
#   array([[418, 149,  84,  84],
#          [384,  43, 153, 153],
#          [972, 117, 130, 130]], dtype=int32)],
#  [True,
#   array([[861,  58, 142, 142],
#          [278,  67, 264, 264]], dtype=int32)],
#  [True,
#   array([[539, 111, 188, 188],
#          [336, 274,  89,  89],
#          [167, 287,  71,  71],
#          [858, 316,  89,  89],
#          [987, 315,  69,  69]], dtype=int32)],
#  [True, array([[290, 258, 104, 104]], dtype=int32)],
#  [True,
#   array([[824,  81,  63,  63],
#          [ 71, 139,  69,  69],
#          [305, 385,  82,  82]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [True,
#   array([[  93,  118,  216,  216],
#          [1084,  216,   65,   65],
#          [1134,  216,   65,   65]], dtype=int32)],
#  [False, ''],
#  [True, array([[759, 313,  66,  66]], dtype=int32)],
#  [True, array([[519,  72, 160, 160]], dtype=int32)],
#  [False, ''],
#  [True, array([[833,   5,  43,  43]], dtype=int32)],
#  [True,
#   array([[861,  80, 221, 221],
#          [200,  79, 230, 230]], dtype=int32)],
#  [True, array([[648, 209,  23,  23]], dtype=int32)],
#  [True,
#   array([[617,  68, 203, 203],
#          [ 16, 567,  47,  47]], dtype=int32)],
#  [True,
#   array([[727, 117, 407, 407],
#          [ 82, 455, 152, 152]], dtype=int32)],
#  [True,
#   array([[115, 108, 134, 134],
#          [315, 208, 118, 118],
#          [966, 196, 235, 235]], dtype=int32)],
#  [True,
#   array([[862,  49, 143, 143],
#          [219,  65, 165, 165]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[397, 111, 385, 385]], dtype=int32)],
#  [True, array([[486, 150, 101, 101]], dtype=int32)],
#  [True, array([[394, 123,  75,  75]], dtype=int32)],
#  [True, array([[510, 384,  84,  84]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[591, 230, 100, 100]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 765,   10,  180,  180],
#          [1008,  120,  126,  126]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[600, 256,  58,  58]], dtype=int32)],
#  [True,
#   array([[574, 116, 190, 190],
#          [998, 144, 192, 192]], dtype=int32)],
#  [True,
#   array([[781, 162, 329, 329],
#          [ 60, 182, 353, 353],
#          [455, 204, 320, 320]], dtype=int32)],
#  [True, array([[733,  88, 132, 132]], dtype=int32)],
#  [True,
#   array([[195,  98, 169, 169],
#          [228, 219,  96,  96]], dtype=int32)],
#  [True, array([[178,  64, 305, 305]], dtype=int32)],
#  [True, array([[544,  83, 176, 176]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[349, 537,  73,  73]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[364,  87, 480, 480]], dtype=int32)],
#  [True,
#   array([[ 851,   63,  112,  112],
#          [1024,  127,  113,  113]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[976,  58, 273, 273],
#          [553, 183, 198, 198]], dtype=int32)],
#  [True,
#   array([[1057,   79,  138,  138],
#          [1119,  209,  107,  107]], dtype=int32)],
#  [True, array([[447, 480,  48,  48]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[625,  96, 107, 107],
#          [850, 139, 115, 115],
#          [155, 139, 332, 332]], dtype=int32)],
#  [True, array([[157, 139, 389, 389]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[393,  34, 197, 197]], dtype=int32)],
#  [True,
#   array([[644, 195,  43,  43],
#          [987, 301,  45,  45]], dtype=int32)],
#  [True, array([[544,  91, 250, 250]], dtype=int32)],
#  [True,
#   array([[824,  90, 304, 304],
#          [273, 160, 257, 257],
#          [180, 455,  46,  46]], dtype=int32)],
#  [True,
#   array([[619, 252,  42,  42],
#          [710, 277,  43,  43],
#          [900, 228,  54,  54],
#          [739, 394,  48,  48],
#          [455, 416,  46,  46],
#          [344, 436,  43,  43],
#          [244, 451,  43,  43],
#          [964, 461,  41,  41]], dtype=int32)],
#  [True,
#   array([[979,  31,  63,  63],
#          [955,  94, 159, 159],
#          [224, 109, 163, 163]], dtype=int32)],
#  [True,
#   array([[548,  94, 105, 105],
#          [505, 125, 125, 125],
#          [546, 179, 106, 106],
#          [510, 212, 128, 128],
#          [504, 300, 125, 125],
#          [540, 351, 106, 106]], dtype=int32)],
#  [True,
#   array([[858,  99, 262, 262],
#          [945, 372,  64,  64]], dtype=int32)],
#  [False, ''],
#  [True, array([[1038,   70,  189,  189]], dtype=int32)],
#  [True, array([[541, 127, 238, 238]], dtype=int32)],
#  [False, ''],
#  [True, array([[955,  23, 114, 114]], dtype=int32)],
#  [True, array([[ 27, 410,  53,  53]], dtype=int32)],
#  [True,
#   array([[743, 112, 258, 258],
#          [280, 113, 302, 302]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[456,  41,  84,  84]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[179,  80, 390, 390]], dtype=int32)],
#  [False, ''],
#  [True, array([[ 69, 198, 460, 460]], dtype=int32)],
#  [True,
#   array([[401,  42, 486, 486],
#          [ 63, 183, 394, 394]], dtype=int32)],
#  [True, array([[960, 125,  91,  91]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[603,  66, 206, 206],
#          [795,  76, 284, 284],
#          [450, 261, 262, 262]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[877, 427,  59,  59],
#          [884, 448,  53,  53]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[1037,  152,   93,   93],
#          [ 740,  165,   90,   90],
#          [ 460,  298,   30,   30]], dtype=int32)],
#  [True, array([[802, 224, 140, 140]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[326,  98,  78,  78],
#          [584, 189, 147, 147]], dtype=int32)],
#  [True,
#   array([[434, 125, 372, 372],
#          [918, 193, 335, 335],
#          [ 62, 171, 260, 260],
#          [553, 314,  95,  95]], dtype=int32)],
#  [True,
#   array([[581,  95, 136, 136],
#          [529, 403,  54,  54],
#          [474, 349, 158, 158]], dtype=int32)],
#  [True, array([[479, 326, 120, 120]], dtype=int32)],
#  [True, array([[361,   9, 107, 107]], dtype=int32)],
#  [True, array([[ 66, 491,  54,  54]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[  30,   24,  187,  187],
#          [1037,   80,  225,  225],
#          [ 703,  262,  119,  119],
#          [ 501,  278,  124,  124],
#          [ 899,  316,  184,  184],
#          [ 154,  308,  137,  137],
#          [ 569,  437,  118,  118],
#          [   6,  440,  115,  115],
#          [ 763,  417,  122,  122],
#          [ 362,  458,  141,  141]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[586,  88, 303, 303]], dtype=int32)],
#  [True, array([[506, 147, 271, 271]], dtype=int32)],
#  [True,
#   array([[375, 203,  53,  53],
#          [909, 212,  50,  50],
#          [185, 418,  54,  54]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True, array([[837, 288, 289, 289]], dtype=int32)],
#  [True, array([[1132,   79,   28,   28]], dtype=int32)],
#  [True,
#   array([[951, 179, 190, 190],
#          [159, 183, 198, 198]], dtype=int32)],
#  [True, array([[548, 260, 193, 193]], dtype=int32)],
#  [True,
#   array([[633, 211, 187, 187],
#          [638, 444, 160, 160]], dtype=int32)],
#  [True, array([[645, 193, 243, 243]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[228,  21, 123, 123],
#          [999,  64, 113, 113],
#          [199, 215,  50,  50],
#          [290, 242,  51,  51],
#          [220, 283,  55,  55],
#          [157, 346,  47,  47],
#          [311, 318,  51,  51],
#          [387, 359,  47,  47],
#          [240, 364,  56,  56],
#          [332, 394,  55,  55],
#          [171, 424,  57,  57],
#          [404, 433,  55,  55],
#          [259, 446,  55,  55],
#          [349, 478,  54,  54],
#          [965, 477, 104, 104],
#          [189, 505,  57,  57],
#          [422, 515,  48,  48],
#          [277, 528,  53,  53],
#          [489, 554,  47,  47],
#          [125, 574,  52,  52],
#          [208, 587,  56,  56],
#          [364, 561,  50,  50],
#          [295, 608,  54,  54],
#          [386, 623,  52,  52],
#          [442, 596,  45,  45],
#          [233, 671,  46,  46],
#          [140, 653,  56,  56]], dtype=int32)],
#  [True,
#   array([[867, 126, 259, 259],
#          [134, 529,  84,  84]], dtype=int32)],
#  [True,
#   array([[845, 318,  50,  50],
#          [310, 270, 128, 128],
#          [917, 271, 131, 131],
#          [662, 497,  66,  66]], dtype=int32)],
#  [True,
#   array([[938, 112, 256, 256],
#          [ 99, 130, 245, 245]], dtype=int32)],
#  [True, array([[521, 212, 269, 269]], dtype=int32)],
#  [True, array([[496, 121, 178, 178]], dtype=int32)],
#  [True, array([[878,   6, 175, 175]], dtype=int32)],
#  [True, array([[549, 148, 163, 163]], dtype=int32)],
#  [True,
#   array([[853, 158,  44,  44],
#          [207, 489,  82,  82]], dtype=int32)],
#  [True,
#   array([[987,  24, 113, 113],
#          [477,  76, 102, 102],
#          [655, 185, 103, 103],
#          [492, 206, 115, 115]], dtype=int32)],
#  [True, array([[453,  72, 149, 149]], dtype=int32)],
#  [True,
#   array([[961, 112,  67,  67],
#          [252,  43,  77,  77]], dtype=int32)],
#  [True, array([[234, 198, 347, 347]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[814,  44,  62,  62]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[902, 135, 120, 120],
#          [755, 250,  67,  67]], dtype=int32)],
#  [True,
#   array([[979, 132, 118, 118],
#          [272, 169,  52,  52]], dtype=int32)],
#  [True, array([[560,  95, 225, 225]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  ['exception', ''],
#  ['exception', ''],
#  [True, array([[ 72, 287, 194, 194]], dtype=int32)],
#  [True,
#   array([[610, 126,  58,  58],
#          [483, 137,  55,  55],
#          [596, 354,  69,  69],
#          [180, 388,  65,  65]], dtype=int32)],
#  [True, array([[390,  14, 549, 549]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[776, 134, 235, 235],
#          [466, 102, 358, 358]], dtype=int32)],
#  [True,
#   array([[1062,  138,   56,   56],
#          [ 887,  230,   34,   34],
#          [ 990,  218,   44,   44],
#          [ 932,  337,   50,   50],
#          [ 998,  346,   51,   51]], dtype=int32)],
#  [True, array([[385, 445,  69,  69]], dtype=int32)],
#  [True,
#   array([[ 423,  192,   84,   84],
#          [ 160,  266,   82,   82],
#          [1031,  261,   90,   90],
#          [1133,  264,  117,  117],
#          [ 906,  374,   84,   84],
#          [ 303,  433,   70,   70]], dtype=int32)],
#  [True, array([[388, 118, 282, 282]], dtype=int32)],
#  [True,
#   array([[1186,  290,   83,   83],
#          [1042,  270,   96,   96]], dtype=int32)],
#  [True, array([[532,  93, 197, 197]], dtype=int32)],
#  [False, ''],
#  [True, array([[545,  44,  59,  59]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[219, 151, 201, 201],
#          [591, 210, 181, 181]], dtype=int32)],
#  [True, array([[ 87,  43, 434, 434]], dtype=int32)],
#  [True,
#   array([[534, 216, 132, 132],
#          [440, 246, 103, 103],
#          [ 69, 266,  86,  86],
#          [384, 285,  54,  54],
#          [911, 322,  53,  53],
#          [314, 302,  56,  56],
#          [212, 303,  74,  74]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[256, 239, 204, 204]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[152, 111, 234, 234],
#          [793, 108, 243, 243]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 488,   44,   75,   75],
#          [ 767,  112,   62,   62],
#          [1129,  245,   63,   63],
#          [1042,  538,   66,   66]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[141,  85, 270, 270],
#          [895,  61, 283, 283]], dtype=int32)],
#  [True, array([[389, 150, 220, 220]], dtype=int32)],
#  [False, ''],
#  [True, array([[605, 449,  72,  72]], dtype=int32)],
#  [True, array([[332,  87, 512, 512]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[410, 206,  29,  29],
#          [297, 242,  30,  30]], dtype=int32)],
#  [False, ''],
#  [True, array([[597, 135, 290, 290]], dtype=int32)],
#  ['exception', ''],
#  ['exception', ''],
#  [True,
#   array([[ 199,  320,   72,   72],
#          [1100,  628,   41,   41],
#          [1070,  629,   43,   43]], dtype=int32)],
#  [True, array([[423, 146, 386, 386]], dtype=int32)],
#  [True,
#   array([[524, 152, 121, 121],
#          [178, 359,  28,  28]], dtype=int32)],
#  [True,
#   array([[726, 132, 318, 318],
#          [162, 145, 307, 307]], dtype=int32)],
#  [True,
#   array([[882, 119, 217, 217],
#          [665, 183, 118, 118],
#          [468, 290,  52,  52]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 887,   61,  175,  175],
#          [ 445,  171,  317,  317],
#          [1057,  593,  122,  122]], dtype=int32)],
#  [True, array([[ 46, 494,  72,  72]], dtype=int32)],
#  [False, ''],
#  [True, array([[434,  69, 170, 170]], dtype=int32)],
#  [True, array([[476, 205, 208, 208]], dtype=int32)],
#  [True,
#   array([[153, 100, 398, 398],
#          [177, 519, 112, 112]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[365, 143, 254, 254],
#          [ 71, 632,  63,  63]], dtype=int32)],
#  [True, array([[ 21, 275,  51,  51]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[964, 232,  90,  90],
#          [498, 420, 221, 221]], dtype=int32)],
#  [True,
#   array([[ 504,  166,   52,   52],
#          [ 910,  247,   47,   47],
#          [1126,  278,   41,   41]], dtype=int32)],
#  [True, array([[460, 117, 238, 238]], dtype=int32)],
#  [True, array([[570,  86, 173, 173]], dtype=int32)],
#  [True,
#   array([[579, 121, 215, 215],
#          [ 10, 388, 100, 100]], dtype=int32)],
#  [True, array([[534, 137, 244, 244]], dtype=int32)],
#  [False, ''],
#  [True, array([[435, 128, 282, 282]], dtype=int32)],
#  [True,
#   array([[215, 102, 224, 224],
#          [864, 104, 232, 232]], dtype=int32)],
#  [False, ''],
#  [True, array([[736, 101, 280, 280]], dtype=int32)],
#  ['exception', ''],
#  ['exception', ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[570, 274,  98,  98]], dtype=int32)],
#  [False, ''],
#  [True, array([[1018,  588,   56,   56]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[829,  70, 398, 398],
#          [440, 116, 414, 414],
#          [155, 109, 336, 336]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [True, array([[527, 125, 183, 183]], dtype=int32)],
#  [True,
#   array([[539, 111, 188, 188],
#          [336, 274,  89,  89],
#          [167, 287,  71,  71],
#          [858, 316,  89,  89],
#          [987, 315,  69,  69]], dtype=int32)],
#  [True,
#   array([[290, 145,  88,  88],
#          [934, 194,  69,  69]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[172, 100, 289, 289],
#          [810, 160, 233, 233]], dtype=int32)],
#  [True, array([[984, 180,  45,  45]], dtype=int32)],
#  [True,
#   array([[106,  56, 310, 310],
#          [646,  65, 282, 282],
#          [199, 346, 114, 114]], dtype=int32)],
#  [True,
#   array([[189, 120, 373, 373],
#          [747, 470,  48,  48],
#          [748, 564,  61,  61]], dtype=int32)],
#  [True, array([[290, 258, 104, 104]], dtype=int32)],
#  [True,
#   array([[861,  58, 142, 142],
#          [278,  67, 264, 264]], dtype=int32)],
#  [True, array([[258, 172, 272, 272]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [True,
#   array([[764, 149, 209, 209],
#          [542, 228, 200, 200],
#          [303, 317,  65,  65]], dtype=int32)],
#  [False, ''],
#  [True, array([[759, 313,  66,  66]], dtype=int32)],
#  [True, array([[519,  72, 160, 160]], dtype=int32)],
#  [True,
#   array([[617,  68, 203, 203],
#          [ 16, 567,  47,  47]], dtype=int32)],
#  [True, array([[648, 209,  23,  23]], dtype=int32)],
#  [True,
#   array([[861,  80, 221, 221],
#          [200,  79, 230, 230]], dtype=int32)],
#  [True,
#   array([[  93,  118,  216,  216],
#          [1084,  216,   65,   65],
#          [1134,  216,   65,   65]], dtype=int32)],
#  [True,
#   array([[824,  81,  63,  63],
#          [ 71, 139,  69,  69],
#          [305, 385,  82,  82]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[115, 108, 134, 134],
#          [966, 196, 235, 235],
#          [315, 208, 118, 118]], dtype=int32)],
#  [True,
#   array([[862,  49, 143, 143],
#          [219,  65, 165, 165]], dtype=int32)],
#  [True,
#   array([[727, 117, 407, 407],
#          [ 82, 455, 152, 152]], dtype=int32)],
#  [True, array([[486, 150, 101, 101]], dtype=int32)],
#  [True, array([[394, 123,  75,  75]], dtype=int32)],
#  [True, array([[833,   5,  43,  43]], dtype=int32)],
#  [False, ''],
#  [True, array([[397, 111, 385, 385]], dtype=int32)],
#  [True, array([[510, 384,  84,  84]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[574, 116, 190, 190],
#          [998, 144, 192, 192]], dtype=int32)],
#  [True, array([[591, 230, 100, 100]], dtype=int32)],
#  [True,
#   array([[ 765,   10,  180,  180],
#          [1008,  120,  126,  126]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[157, 139, 389, 389]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[781, 162, 329, 329],
#          [ 60, 182, 353, 353],
#          [455, 204, 320, 320]], dtype=int32)],
#  [True, array([[600, 256,  58,  58]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[195,  98, 169, 169],
#          [228, 219,  96,  96]], dtype=int32)],
#  [True, array([[178,  64, 305, 305]], dtype=int32)],
#  [True, array([[733,  88, 132, 132]], dtype=int32)],
#  [True, array([[544,  83, 176, 176]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[364,  87, 480, 480]], dtype=int32)],
#  [True,
#   array([[384,  43, 153, 153],
#          [972, 117, 130, 130],
#          [418, 149,  84,  84]], dtype=int32)],
#  [True, array([[349, 537,  73,  73]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[1024,  127,  113,  113],
#          [ 851,   63,  112,  112]], dtype=int32)],
#  [True, array([[447, 480,  48,  48]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[1057,   79,  138,  138],
#          [1119,  209,  107,  107]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[625,  96, 107, 107],
#          [850, 139, 115, 115],
#          [155, 139, 332, 332]], dtype=int32)],
#  [True, array([[393,  34, 197, 197]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[644, 195,  43,  43],
#          [987, 301,  45,  45]], dtype=int32)],
#  [True,
#   array([[824,  90, 304, 304],
#          [273, 160, 257, 257],
#          [180, 455,  46,  46]], dtype=int32)],
#  [True,
#   array([[619, 252,  42,  42],
#          [710, 277,  43,  43],
#          [900, 228,  54,  54],
#          [739, 394,  48,  48],
#          [455, 416,  46,  46],
#          [344, 436,  43,  43],
#          [244, 451,  43,  43],
#          [964, 461,  41,  41]], dtype=int32)],
#  [True, array([[304, 493,  86,  86]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 797,  216,  193,  193],
#          [ 138,  232,  176,  176],
#          [1096,  272,  167,  167]], dtype=int32)],
#  [True,
#   array([[1037,  152,   93,   93],
#          [ 740,  165,   90,   90],
#          [ 460,  298,   30,   30]], dtype=int32)],
#  [True, array([[1042,   50,   49,   49]], dtype=int32)],
#  [True,
#   array([[534,  86, 202, 202],
#          [256, 168,  63,  63]], dtype=int32)],
#  [True,
#   array([[847,  44, 356, 356],
#          [111,  33, 416, 416]], dtype=int32)],
#  [False, ''],
#  [True, array([[802, 224, 140, 140]], dtype=int32)],
#  [True, array([[939, 102, 244, 244]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[749, 396, 108, 108]], dtype=int32)],
#  [True,
#   array([[434, 125, 372, 372],
#          [918, 193, 335, 335],
#          [ 62, 171, 260, 260],
#          [553, 314,  95,  95]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[326,  98,  78,  78],
#          [584, 189, 147, 147]], dtype=int32)],
#  [True, array([[479, 326, 120, 120]], dtype=int32)],
#  [True, array([[497, 258, 183, 183]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[700, 119, 281, 281],
#          [382, 483,  48,  48]], dtype=int32)],
#  [True,
#   array([[288, 178,  28,  28],
#          [619, 155,  69,  69]], dtype=int32)],
#  [True, array([[ 66, 491,  54,  54]], dtype=int32)],
#  [True,
#   array([[581,  95, 136, 136],
#          [529, 403,  54,  54],
#          [474, 349, 158, 158]], dtype=int32)],
#  [True, array([[361,   9, 107, 107]], dtype=int32)],
#  [True, array([[341,  66,  97,  97]], dtype=int32)],
#  [True, array([[784, 193,  84,  84]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[670,  79,  67,  67],
#          [518,  57,  75,  75]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[ 14, 123,  50,  50]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[  30,   24,  187,  187],
#          [1037,   80,  225,  225],
#          [ 703,  262,  119,  119],
#          [ 501,  278,  124,  124],
#          [ 899,  316,  184,  184],
#          [ 154,  308,  137,  137],
#          [ 569,  437,  118,  118],
#          [ 763,  417,  122,  122],
#          [   6,  440,  115,  115],
#          [ 362,  458,  141,  141]], dtype=int32)],
#  [False, ''],
#  [True, array([[506, 147, 271, 271]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [True, array([[746, 256,  86,  86]], dtype=int32)],
#  [True,
#   array([[803, 100, 183, 183],
#          [786, 426,  64,  64]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[606,  63, 209, 209],
#          [ 99, 141, 139, 139],
#          [282, 150, 125, 125]], dtype=int32)],
#  [True, array([[996, 350,  46,  46]], dtype=int32)],
#  [True, array([[586,  88, 303, 303]], dtype=int32)],
#  [True,
#   array([[457, 233,  23,  23],
#          [963, 211,  22,  22]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  ['exception', ''],
#  [True,
#   array([[951, 179, 190, 190],
#          [159, 183, 198, 198]], dtype=int32)],
#  [True,
#   array([[633, 211, 187, 187],
#          [638, 444, 160, 160]], dtype=int32)],
#  [False, ''],
#  [True, array([[645, 193, 243, 243]], dtype=int32)],
#  [True, array([[1132,   79,   28,   28]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[999,  64, 113, 113],
#          [228,  21, 123, 123],
#          [199, 215,  50,  50],
#          [290, 242,  51,  51],
#          [220, 283,  55,  55],
#          [311, 318,  51,  51],
#          [157, 346,  47,  47],
#          [387, 359,  47,  47],
#          [240, 364,  56,  56],
#          [332, 394,  55,  55],
#          [171, 424,  57,  57],
#          [404, 433,  55,  55],
#          [349, 478,  54,  54],
#          [259, 446,  55,  55],
#          [965, 477, 104, 104],
#          [189, 505,  57,  57],
#          [422, 515,  48,  48],
#          [277, 528,  53,  53],
#          [489, 554,  47,  47],
#          [125, 574,  52,  52],
#          [208, 587,  56,  56],
#          [364, 561,  50,  50],
#          [386, 623,  52,  52],
#          [295, 608,  54,  54],
#          [140, 653,  56,  56],
#          [442, 596,  45,  45],
#          [233, 671,  46,  46]], dtype=int32)],
#  [True,
#   array([[194, 218, 153, 153],
#          [951, 567,  62,  62]], dtype=int32)],
#  [True,
#   array([[845, 318,  50,  50],
#          [310, 270, 128, 128],
#          [917, 271, 131, 131],
#          [662, 497,  66,  66]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[867, 126, 259, 259],
#          [134, 529,  84,  84]], dtype=int32)],
#  [True, array([[521, 212, 269, 269]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[878,   6, 175, 175]], dtype=int32)],
#  [True, array([[495,  58, 423, 423]], dtype=int32)],
#  [True, array([[496, 121, 178, 178]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 318,   56,   49,   49],
#          [ 174,  292,  183,  183],
#          [1034,  414,   42,   42]], dtype=int32)],
#  [True,
#   array([[853, 158,  44,  44],
#          [207, 489,  82,  82]], dtype=int32)],
#  [False, ''],
#  [True, array([[549, 148, 163, 163]], dtype=int32)],
#  [True,
#   array([[987,  24, 113, 113],
#          [477,  76, 102, 102],
#          [655, 185, 103, 103],
#          [492, 206, 115, 115]], dtype=int32)],
#  [True,
#   array([[457, 120, 344, 344],
#          [205,  41, 217, 217]], dtype=int32)],
#  [True, array([[583,  80, 101, 101]], dtype=int32)],
#  [True, array([[484, 177, 392, 392]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[938, 112, 256, 256],
#          [ 99, 130, 245, 245]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[950, 251,  56,  56],
#          [775, 573,  58,  58]], dtype=int32)],
#  [True, array([[558, 138, 186, 186]], dtype=int32)],
#  [False, ''],
#  [True, array([[453,  72, 149, 149]], dtype=int32)],
#  [False, ''],
#  [True, array([[553, 611,  74,  74]], dtype=int32)],
#  [True, array([[234, 198, 347, 347]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 767,  259,  124,  124],
#          [ 471,  264,  102,  102],
#          [ 926,  297,  105,  105],
#          [1033,  288,  124,  124],
#          [ 350,  293,  146,  146],
#          [ 209,  302,   87,   87]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[961, 112,  67,  67],
#          [252,  43,  77,  77]], dtype=int32)],
#  [True, array([[555, 417, 110, 110]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [False, ''],
#  ['exception', ''],
#  ['exception', ''],
#  [True, array([[814,  44,  62,  62]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[902, 135, 120, 120],
#          [755, 250,  67,  67]], dtype=int32)],
#  [False, ''],
#  [True, array([[560,  95, 225, 225]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[979, 132, 118, 118],
#          [272, 169,  52,  52]], dtype=int32)],
#  ['exception', ''],
#  ['exception', ''],
#  [False, ''],
#  ['exception', ''],
#  [False, ''],
#  [True,
#   array([[610, 126,  58,  58],
#          [483, 137,  55,  55],
#          [596, 354,  69,  69],
#          [180, 388,  65,  65]], dtype=int32)],
#  [True, array([[390,  14, 549, 549]], dtype=int32)],
#  [True,
#   array([[776, 134, 235, 235],
#          [466, 102, 358, 358]], dtype=int32)],
#  [True,
#   array([[1062,  138,   56,   56],
#          [ 887,  230,   34,   34],
#          [ 990,  218,   44,   44],
#          [ 932,  337,   50,   50],
#          [ 998,  346,   51,   51]], dtype=int32)],
#  [True, array([[385, 445,  69,  69]], dtype=int32)],
#  [True, array([[388, 118, 282, 282]], dtype=int32)],
#  [True,
#   array([[ 423,  192,   84,   84],
#          [ 160,  266,   82,   82],
#          [1031,  261,   90,   90],
#          [1133,  264,  117,  117],
#          [ 906,  374,   84,   84],
#          [ 303,  433,   70,   70]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[1186,  290,   83,   83],
#          [1042,  270,   96,   96]], dtype=int32)],
#  [False, ''],
#  [True, array([[532,  93, 197, 197]], dtype=int32)],
#  [False, ''],
#  [True, array([[545,  44,  59,  59]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[219, 151, 201, 201],
#          [591, 210, 181, 181]], dtype=int32)],
#  [False, ''],
#  [True, array([[ 87,  43, 434, 434]], dtype=int32)],
#  [False, ''],
#  [True, array([[256, 239, 204, 204]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[152, 111, 234, 234],
#          [793, 108, 243, 243]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[597, 135, 290, 290]], dtype=int32)],
#  [True,
#   array([[410, 206,  29,  29],
#          [297, 242,  30,  30]], dtype=int32)],
#  [True,
#   array([[ 488,   44,   75,   75],
#          [ 767,  112,   62,   62],
#          [1129,  245,   63,   63],
#          [1042,  538,   66,   66]], dtype=int32)],
#  [True, array([[476, 205, 208, 208]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[534, 216, 132, 132],
#          [440, 246, 103, 103],
#          [ 69, 266,  86,  86],
#          [384, 285,  54,  54],
#          [911, 322,  53,  53],
#          [314, 302,  56,  56],
#          [212, 303,  74,  74]], dtype=int32)],
#  [True,
#   array([[895,  61, 283, 283],
#          [141,  85, 270, 270]], dtype=int32)],
#  [True, array([[389, 150, 220, 220]], dtype=int32)],
#  [True,
#   array([[ 199,  320,   72,   72],
#          [1100,  628,   41,   41],
#          [1070,  629,   43,   43]], dtype=int32)],
#  [True, array([[332,  87, 512, 512]], dtype=int32)],
#  ['exception', ''],
#  [False, ''],
#  [False, ''],
#  [True, array([[605, 449,  72,  72]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[726, 132, 318, 318],
#          [162, 145, 307, 307]], dtype=int32)],
#  [True, array([[423, 146, 386, 386]], dtype=int32)],
#  [True,
#   array([[524, 152, 121, 121],
#          [178, 359,  28,  28]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True, array([[434,  69, 170, 170]], dtype=int32)],
#  [True,
#   array([[ 887,   61,  175,  175],
#          [ 445,  171,  317,  317],
#          [1057,  593,  122,  122]], dtype=int32)],
#  [True, array([[ 46, 494,  72,  72]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[153, 100, 398, 398],
#          [177, 519, 112, 112]], dtype=int32)],
#  [True,
#   array([[882, 119, 217, 217],
#          [665, 183, 118, 118],
#          [468, 290,  52,  52]], dtype=int32)],
#  [True,
#   array([[365, 143, 254, 254],
#          [ 71, 632,  63,  63]], dtype=int32)],
#  [True, array([[ 21, 275,  51,  51]], dtype=int32)],
#  [False, ''],
#  [False, ''],
#  [True,
#   array([[964, 232,  90,  90],
#          [498, 420, 221, 221]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[ 504,  166,   52,   52],
#          [ 910,  247,   47,   47],
#          [1126,  278,   41,   41]], dtype=int32)],
#  [True, array([[460, 117, 238, 238]], dtype=int32)],
#  [True, array([[570,  86, 173, 173]], dtype=int32)],
#  [True,
#   array([[579, 121, 215, 215],
#          [ 10, 388, 100, 100]], dtype=int32)],
#  [True, array([[534, 137, 244, 244]], dtype=int32)],
#  [False, ''],
#  [True, array([[435, 128, 282, 282]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[215, 102, 224, 224],
#          [864, 104, 232, 232]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[736, 101, 280, 280]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [False, ''],
#  [True, array([[570, 274,  98,  98]], dtype=int32)],
#  [True, array([[1018,  588,   56,   56]], dtype=int32)],
#  ['exception', ''],
#  [True,
#   array([[539, 111, 188, 188],
#          [336, 274,  89,  89],
#          [167, 287,  71,  71],
#          [858, 316,  89,  89],
#          [987, 315,  69,  69]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[829,  70, 398, 398],
#          [440, 116, 414, 414],
#          [155, 109, 336, 336]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[527, 125, 183, 183]], dtype=int32)],
#  [False, ''],
#  [True,
#   array([[290, 145,  88,  88],
#          [934, 194,  69,  69]], dtype=int32)],
#  ['exception', ''],
#  [True, array([[984, 180,  45,  45]], dtype=int32)],
#  [True,
#   array([[172, 100, 289, 289],
#          [810, 160, 233, 233]], dtype=int32)],
#  [True,
#   array([[106,  56, 310, 310],
#          [646,  65, 282, 282],
#          [199, 346, 114, 114]], dtype=int32)],
#  [True,
#   array([[189, 120, 373, 373],
#          [747, 470,  48,  48],
#          [748, 564,  61,  61]], dtype=int32)],
#  [True, array([[290, 258, 104, 104]], dtype=int32)],
#  [False, ''],
#  ['exception', ''],
#  [True,
#   array([[861,  58, 142, 142],
#          [278,  67, 264, 264]], dtype=int32)],
#  [False, ''],
#  [True, array([[759, 313,  66,  66]], dtype=int32)],
#  ...]

# %%
newArray = []
for i in range(len(results)):
    newArray.append(results[i][0])

# %%
newArray.count(True)/(newArray.count(True)+newArray.count(False))
# Out:
# 0.6381357873835345

# %%
df['faces_detected'] = newArray

# %%
df.to_csv('US_youtube_trending_data_with_faces.csv', encoding='utf-8', index=False)
